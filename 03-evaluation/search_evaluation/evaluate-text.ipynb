# %%
import json

with open('documents-with-ids.json', 'rt') as f_in:
    documents = json.load(f_in)

# %%
import os
from elasticsearch import Elasticsearch

es_client = Elasticsearch('https://localhost:9200',
            basic_auth=(
                os.getenv("ES_USER"), 
                os.getenv("ES_PASSWORD")),
            verify_certs=False)

                          
index_settings = {
    "settings": {
        "number_of_shards": 1,
        "number_of_replicas": 0
    },
    "mappings": {
        "properties": {
            "text": {"type": "text"},
            "section": {"type": "text"},
            "question": {"type": "text"},
            "course": {"type": "keyword"},
            "id": {"type": "keyword"},
        }
    }
}

index_name = "course-questions"

es_client.indices.delete(index=index_name, ignore_unavailable=True)
es_client.indices.create(index=index_name, body=index_settings)
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/elasticsearch/_sync/client/__init__.py:397: SecurityWarning: Connecting to 'https://localhost:9200' using TLS with verify_certs=False is insecure
#   _transport = transport_class(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'course-questions'})

# %%
from tqdm.auto import tqdm

for doc in tqdm(documents):
    es_client.index(index=index_name, document=doc)
# Out:
#   0%|          | 0/948 [00:00<?, ?it/s]
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ...
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
def elastic_search(query, course):
    search_query = {
        "size": 5,
        "query": {
            "bool": {
                "must": {
                    "multi_match": {
                        "query": query,
                        "fields": ["question^3", "text", "section"],
                        "type": "best_fields"
                    }
                },
                "filter": {
                    "term": {
                        "course": course
                    }
                }
            }
        }
    }

    response = es_client.search(index=index_name, body=search_query)
    
    result_docs = []
    
    for hit in response['hits']['hits']:
        result_docs.append(hit['_source'])
    
    return result_docs

# %%
elastic_search(
    query="I just discovered the course. Can I still join?",
    course="data-engineering-zoomcamp"
)
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# [{'text': "Yes, even if you don't register, you're still eligible to submit the homeworks.\nBe aware, however, that there will be deadlines for turning in the final projects. So don't leave everything for the last minute.",
#   'section': 'General course-related questions',
#   'question': 'Course - Can I still join the course after the start date?',
#   'course': 'data-engineering-zoomcamp',
#   'id': '7842b56a'},
#  {'text': 'You can start by installing and setting up all the dependencies and requirements:\nGoogle cloud account\nGoogle Cloud SDK\nPython 3 (installed with Anaconda)\nTerraform\nGit\nLook over the prerequisites and syllabus to see if you are comfortable with these subjects.',
#   'section': 'General course-related questions',
#   'question': 'Course - What can I do before the course starts?',
#   'course': 'data-engineering-zoomcamp',
#   'id': '63394d91'},
#  {'text': 'Yes, we will keep all the materials after the course finishes, so you can follow the course at your own pace after it finishes.\nYou can also continue looking at the homeworks and continue preparing for the next cohort. I guess you can also start working on your final capstone project.',
#   'section': 'General course-related questions',
#   'question': 'Course - Can I follow the course after it finishes?',
#   'course': 'data-engineering-zoomcamp',
#   'id': 'a482086d'},
#  {'text': 'Yes, the slack channel remains open and you can ask questions there. But always sDocker containers exit code w search the channel first and second, check the FAQ (this document), most likely all your questions are already answered here.\nYou can also tag the bot @ZoomcampQABot to help you conduct the search, but don’t rely on its answers 100%, it is pretty good though.',
#   'section': 'General course-related questions',
#   'question': 'Course - Can I get support if I take the course in the self-paced mode?',
#   'course': 'data-engineering-zoomcamp',
#   'id': 'eb56ae98'},
#  {'text': "You don't need it. You're accepted. You can also just start learning and submitting homework without registering. It is not checked against any registered list. Registration is just to gauge interest before the start date.",
#   'section': 'General course-related questions',
#   'question': 'Course - I have registered for the Data Engineering Bootcamp. When can I expect to receive the confirmation email?',
#   'course': 'data-engineering-zoomcamp',
#   'id': '0bbf41ec'}]

# %%
import pandas as pd

# %%
df_ground_truth = pd.read_csv('ground-truth-data.csv')

# %%
ground_truth = df_ground_truth.to_dict(orient='records')

# %%
ground_truth
# Out:
# [{'question': 'What is the specific date and time when the course officially begins?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'c02e79ef'},
#  {'question': 'How can I add the course schedule to my personal calendar to stay updated?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'c02e79ef'},
#  {'question': 'Is there a registration link I need to use before the course starts, and where can I find it?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'c02e79ef'},
#  {'question': 'Where should I go to receive important announcements about the course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'c02e79ef'},
#  {'question': 'Do I need to join any communication platforms like Slack or Telegram for this course, and how?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'c02e79ef'},
#  {'question': 'What prior knowledge or skills do I need before enrolling in this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1f6520ca'},
#  {'question': 'Are there any specific tools or technologies I should be familiar with before starting?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1f6520ca'},
#  {'question': 'Does the course require experience with programming languages or frameworks?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1f6520ca'},
#  {'question': 'Where can I find the list of requirements to take this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1f6520ca'},
#  {'question': 'Is there a recommended background or preparation guide for this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1f6520ca'},
#  {'question': 'Is it possible to enroll in the course after the official start date has already passed?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7842b56a'},
#  {'question': 'What happens if I decide to join the course late but haven’t registered yet?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7842b56a'},
#  {'question': 'Are there any consequences for submitting assignments if I sign up after the course begins?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7842b56a'},
#  {'question': 'How does starting the course late affect the deadlines for completing the final projects?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7842b56a'},
#  {'question': 'If I miss the initial registration period, can I still hand in all the required work before the final cutoff?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7842b56a'},
#  {'question': 'What should I do if I signed up for the Data Engineering Bootcamp but haven’t gotten any confirmation email yet?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0bbf41ec'},
#  {'question': 'Is it necessary to wait for an acceptance notification before I can begin the coursework?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0bbf41ec'},
#  {'question': 'Do I need to show proof of registration when submitting assignments for the bootcamp?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0bbf41ec'},
#  {'question': 'If I didn’t officially register, can I still participate in the course and turn in homework?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0bbf41ec'},
#  {'question': 'Why does the registration process exist if it doesn’t affect my ability to start the course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0bbf41ec'},
#  {'question': 'What steps should I take to prepare my system before the first class session?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '63394d91'},
#  {'question': 'Which specific tools and software will I need to install ahead of time?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '63394d91'},
#  {'question': 'Is there a recommended way to set up my development environment for this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '63394d91'},
#  {'question': 'How can I check if I meet the necessary background knowledge for the course material?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '63394d91'},
#  {'question': 'Are there any documents or resources I should review before the course begins?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '63394d91'},
#  {'question': 'How often are the Zoomcamps held throughout the year, and do they cover different topics?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2ed9b986'},
#  {'question': 'Is there a specific timeframe for the Data-Engineering Zoomcamp, and does it repeat within the same year?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2ed9b986'},
#  {'question': 'Can I join a Zoomcamp outside of the scheduled live cohort if I don’t need the certification?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2ed9b986'},
#  {'question': 'Are the start and end dates for each Zoomcamp the same every year, or do they vary slightly?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2ed9b986'},
#  {'question': 'If I want to earn a certificate, do I have to participate in the live cohort, or are there other options?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2ed9b986'},
#  {'question': 'What changes have been made to the course content for the 2024 cohort compared to last year?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '93e2c8ed'},
#  {'question': "Will the tools used in this year's course be the same as those in the previous edition?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '93e2c8ed'},
#  {'question': 'Can you explain why Mage AI is being introduced instead of Prefect in the 2024 version?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '93e2c8ed'},
#  {'question': 'Are there any updates to the Terraform materials, and if so, how do they differ from the 2023 videos?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '93e2c8ed'},
#  {'question': 'Which workflow orchestration tool was used in the 2023 cohort, and how does it compare to the one in 2024?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '93e2c8ed'},
#  {'question': 'Will the course content still be accessible once the official sessions are over?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a482086d'},
#  {'question': 'Is it possible to review the lessons and assignments even after the course end date?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a482086d'},
#  {'question': 'Can I keep working on the coursework if I don’t finish everything before the deadline?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a482086d'},
#  {'question': 'Are there any restrictions on how long I can access the materials after the course concludes?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a482086d'},
#  {'question': 'If I miss the live sessions, can I still complete the course and submit the final project later?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a482086d'},
#  {'question': "What kind of help is available if I'm doing the course on my own without a fixed schedule?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'eb56ae98'},
#  {'question': "Is there a way to get answers to my questions when I'm studying independently?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'eb56ae98'},
#  {'question': 'How can I find solutions to common problems without waiting for a response from the instructors?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'eb56ae98'},
#  {'question': 'Can I use a tool to search for answers in the community discussions before asking my question?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'eb56ae98'},
#  {'question': 'What should I do first if I run into an issue while taking the course in self-paced mode?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'eb56ae98'},
#  {'question': 'How can I find the primary video resources for this course on YouTube?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '4292531b'},
#  {'question': 'Is there a way to see previews of the videos before watching them, like thumbnails?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '4292531b'},
#  {'question': 'Where should I look for extra videos, such as office hours, if I need more content?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '4292531b'},
#  {'question': 'I noticed there’s a Slack channel for the course—how do I access the YouTube playlist from there?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '4292531b'},
#  {'question': 'Could you clarify whether the main playlist includes all the videos or just the core ones?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '4292531b'},
#  {'question': 'What’s the typical time commitment for this course each week?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ea739c65'},
#  {'question': 'How much time should I plan to dedicate to coursework if I’m new to the subject?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ea739c65'},
#  {'question': 'Is there a recommended weekly study schedule for this class?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ea739c65'},
#  {'question': 'Can the weekly workload vary significantly based on my prior knowledge?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ea739c65'},
#  {'question': 'Are there any tools or guidelines to estimate how much time I’ll need per week?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ea739c65'},
#  {'question': 'Is it possible to earn a certificate if I complete the course on my own schedule without joining a live group?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'cb257ee5'},
#  {'question': 'What are the requirements for receiving a certificate after finishing the course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'cb257ee5'},
#  {'question': 'Can I still get a certificate if I work through the material independently instead of with a cohort?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'cb257ee5'},
#  {'question': 'Why isn’t a certificate available for those who take the course at their own pace?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'cb257ee5'},
#  {'question': 'Do I need to participate in peer reviews to qualify for a certificate, and how does that work?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'cb257ee5'},
#  {'question': "How can I join the live Office Hour or workshop sessions if I'm a student?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '04aa4897'},
#  {'question': 'Where should I look for the link to watch the Office Hours on YouTube?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '04aa4897'},
#  {'question': 'What’s the best way to ask questions during the live stream without them getting lost?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '04aa4897'},
#  {'question': 'Is there a specific platform where I can submit my questions for the instructor to see?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '04aa4897'},
#  {'question': 'Why isn’t the Zoom link for Office Hours shared with students directly?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '04aa4897'},
#  {'question': 'What should I do if I miss the live Office Hours session?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '9681be3b'},
#  {'question': 'How soon after the workshop ends can I access the recording?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '9681be3b'},
#  {'question': 'Can I watch the Office Hours recordings more than once if I need to?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '9681be3b'},
#  {'question': 'Is there a specific place where I can find the recorded sessions?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '9681be3b'},
#  {'question': 'Do I need to notify anyone if I plan to watch the Office Hours later instead of attending live?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '9681be3b'},
#  {'question': 'Where can I check the most current due dates for assignments and projects in this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1daf537'},
#  {'question': 'Is there a specific place I should look for last-minute changes to homework deadlines?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1daf537'},
#  {'question': 'How will I know if an assignment deadline has been extended or modified?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1daf537'},
#  {'question': 'Besides the spreadsheet, what other ways will I be notified about updates to project timelines?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1daf537'},
#  {'question': 'What should I do if the deadline shown in the submission form doesn’t match the one in the spreadsheet?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1daf537'},
#  {'question': 'What happens if I miss the deadline for submitting my homework?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'be5bfee4'},
#  {'question': 'Is there any way to turn in an assignment after the due date has passed?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'be5bfee4'},
#  {'question': 'How can I ensure my homework is accepted if I submit it right after the deadline?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'be5bfee4'},
#  {'question': 'Does the course allow any flexibility for late submissions under certain conditions?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'be5bfee4'},
#  {'question': 'What should I check to confirm that my late homework submission was recorded correctly?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'be5bfee4'},
#  {'question': 'How can I find the correct link to submit my homework assignments?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0e424a44'},
#  {'question': 'Where should I upload or store my completed exercises for this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0e424a44'},
#  {'question': 'Is there a specific platform I need to use to share my weekly coding work?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0e424a44'},
#  {'question': 'What counts as a valid location for my homework submissions according to the course guidelines?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0e424a44'},
#  {'question': 'Can I use any online repository for my assignments, or are there preferred options?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0e424a44'},
#  {'question': 'questions',
#   'course': 'data-engineering-zoomcamp',
#   'document': '29865466'},
#  {'question': 'How can I find out what my assigned name is on the course leaderboard?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '016d46a1'},
#  {'question': 'Where do I check the username that appears on the leaderboard for my submissions?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '016d46a1'},
#  {'question': 'Is there a way to see the random name I was given for the leaderboard, and can I change it?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '016d46a1'},
#  {'question': 'What steps do I follow to locate my display name used in the course rankings?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '016d46a1'},
#  {'question': 'If I don’t recognize my name on the leaderboard, how do I verify which one is mine?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '016d46a1'},
#  {'question': 'What is the best Python version to install for this course in 2024?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '47972cb1'},
#  {'question': 'Should I use the latest Python version, or is an older one preferred for this class?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '47972cb1'},
#  {'question': 'Will I run into issues if I use Python 3.10 or 3.11 instead of 3.9?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '47972cb1'},
#  {'question': 'Why does the course recommend Python 3.9 specifically when newer versions are available?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '47972cb1'},
#  {'question': 'Is there a risk of compatibility problems if I don’t use Python 3.9 for the coursework?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '47972cb1'},
#  {'question': 'What are the main advantages of using a cloud-based environment like GitHub Codespaces instead of my own computer for this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ddf6c1b3'},
#  {'question': 'If I choose to work locally on my Windows machine, what kind of issues might I encounter during setup?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ddf6c1b3'},
#  {'question': 'Can you explain why someone might prefer a virtual machine over installing everything directly on their laptop?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ddf6c1b3'},
#  {'question': 'For the first week, should I focus on Docker first if I plan to use my local machine, or is there another recommended starting point?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ddf6c1b3'},
#  {'question': 'How flexible is it to switch between different devices (like home and office PCs) if I use a cloud-based setup instead of a local one?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ddf6c1b3'},
#  {'question': 'Can I use GitHub Codespaces instead of setting up a local command-line interface like Git Bash for handling data and Docker tasks?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ac25d3af'},
#  {'question': 'Does GitHub Codespaces come with Docker and other necessary tools already installed, or do I need to configure them myself?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ac25d3af'},
#  {'question': 'Is it possible to work directly on a GitHub repository through Codespaces without cloning it to my local machine first?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ac25d3af'},
#  {'question': 'How does using GitHub Codespaces compare to running Docker and Git commands on my own computer in terms of performance and convenience?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ac25d3af'},
#  {'question': 'Are there any limitations or additional steps required when using GitHub Codespaces for tasks that typically involve local CLI tools?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'ac25d3af'},
#  {'question': 'Is it mandatory to set up GitHub Codespaces for this course, or can I work with my existing local setup?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '251218fc'},
#  {'question': 'What are the advantages of using GitHub Codespaces over my own Docker and PostgreSQL installation?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '251218fc'},
#  {'question': 'Are there any specific requirements for the development environment that I should be aware of if I don’t use the recommended options?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '251218fc'},
#  {'question': 'Will I face any limitations or compatibility issues if I choose to complete the course using my local machine instead of the suggested platforms?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '251218fc'},
#  {'question': 'Can I switch between different environments (like my laptop and GitHub Codespaces) during the course, or is it better to stick with one?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '251218fc'},
#  {'question': "Which development environment should I prioritize if I want to focus on the course's end project?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '3c0114ce'},
#  {'question': 'Is it necessary to use both GitHub Codespaces and Google Cloud Platform (GCP) for this course, or can I pick just one?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '3c0114ce'},
#  {'question': 'Since BigQuery is part of GCP, does that mean I should avoid GitHub Codespaces entirely?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '3c0114ce'},
#  {'question': 'Can I complete most of the coursework using a local setup instead of cloud-based tools like GCP or Codespaces?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '3c0114ce'},
#  {'question': 'What are the advantages of learning GCP over GitHub Codespaces for this course, given that BigQuery is required?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '3c0114ce'},
#  {'question': 'How do I quickly open the Run command window on a Windows computer if I need to access the registry editor?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f43f5fe7'},
#  {'question': 'What steps should I follow to locate and modify registry values in the Windows Registry Editor?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f43f5fe7'},
#  {'question': "Where exactly can I find the 'Autorun' registry value that needs to be adjusted for connecting to a GCP VM via VSCode?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f43f5fe7'},
#  {'question': 'Instead of changing the registry, is there another way to resolve the connection issue with my GCP VM in VSCode?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f43f5fe7'},
#  {'question': 'Where is the known_hosts file stored on a Windows machine, and how can I delete the saved fingerprint?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f43f5fe7'},
#  {'question': 'What are the main reasons the course recommends using Google Cloud Platform (GCP) instead of other cloud services?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'd061525d'},
#  {'question': 'Can I complete the course assignments using a different cloud provider like AWS or Azure, or is GCP mandatory?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'd061525d'},
#  {'question': 'How much free credit does GCP offer for new users, and what are the requirements to access it?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'd061525d'},
#  {'question': 'Why is BigQuery specifically mentioned as part of the course, and how does it relate to GCP?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'd061525d'},
#  {'question': 'Do I need a credit card to set up a free GCP account, and are there any risks involved in providing one?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'd061525d'},
#  {'question': "Do I need to spend money on cloud platforms for this course if I'm using Google Cloud?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '1cd01b2c'},
#  {'question': 'Is there a way to complete the course without paying for GCP services?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1cd01b2c'},
#  {'question': 'What are my options if I don’t want to incur costs while using cloud resources?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1cd01b2c'},
#  {'question': 'Does the course require purchasing any cloud credits, or are there free alternatives?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1cd01b2c'},
#  {'question': 'Can I rely entirely on the free tier of Google Cloud Platform for all assignments?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1cd01b2c'},
#  {'question': 'questions',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e4a7c3b0'},
#  {'question': 'Can I choose to work with AWS instead of the platform shown in the course materials?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7cd1912e'},
#  {'question': 'Will I face any disadvantages if I decide to use AWS for the assignments and projects?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7cd1912e'},
#  {'question': 'How will the final capstone project be assessed if I use AWS instead of the recommended tool?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7cd1912e'},
#  {'question': 'What should I do if I run into technical issues while using AWS, since the course primarily supports another platform?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7cd1912e'},
#  {'question': 'Are there any specific adjustments I need to make to the course instructions if I use AWS for the data pipeline and visualization tasks?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7cd1912e'},
#  {'question': 'Are there any other scheduled live sessions besides the regular Office Hours?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '52393fb3'},
#  {'question': 'Will there be additional Zoom meetings outside of the usual Office Hours, and if so, when?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '52393fb3'},
#  {'question': 'How will I know if extra live calls are planned during the course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '52393fb3'},
#  {'question': 'Is it possible to have more interactive sessions apart from the standard Office Hours?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '52393fb3'},
#  {'question': 'Can you clarify if there are any other real-time discussions or Q&A sessions beyond Office Hours?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '52393fb3'},
#  {'question': "Is the dataset for this year's project the same as the one used in previous years?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '10515af5'},
#  {'question': 'Will we be analyzing the January 2021 trip records again, or has the data been updated?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '10515af5'},
#  {'question': 'Has there been any change in the source material for the course assignments compared to last year?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '10515af5'},
#  {'question': 'Can you confirm if we’re working with the 2021 NYC Trip data or if a newer version is available?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '10515af5'},
#  {'question': 'Where can I find the dataset we’ll be using for the project this semester?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '10515af5'},
#  {'question': 'Where can I find the materials from the 2022 version of the course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'cdb86a97'},
#  {'question': "Has the repository for the previous year's course been removed permanently?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'cdb86a97'},
#  {'question': 'Are the 2022 course files still accessible somewhere?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'cdb86a97'},
#  {'question': 'Did the instructors delete the old course content, or is it available elsewhere?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'cdb86a97'},
#  {'question': 'What happened to the repository that contained the 2022 course resources?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'cdb86a97'},
#  {'question': 'Is there a specific tool I must use for the final project, or can I choose something else?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '3e0114ad'},
#  {'question': 'Are there any restrictions on the software or frameworks I can use for my project?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '3e0114ad'},
#  {'question': 'Would it be acceptable to complete the final project using a different workflow management system than the one suggested?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '3e0114ad'},
#  {'question': 'Do I have the freedom to select any technology stack for my project, or are there recommended tools?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '3e0114ad'},
#  {'question': 'If I prefer a different platform than the one covered in the course, can I still use it for my final submission?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '3e0114ad'},
#  {'question': "Can I replace the course's recommended tool with a different one, like Airflow or Tableau, for my assignments?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'b2799574'},
#  {'question': 'What are the two main data stack options covered in this course, and can I mix and match tools from both?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'b2799574'},
#  {'question': 'If I decide to use a tool not listed in the course materials, will I still receive help from instructors if I run into issues?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'b2799574'},
#  {'question': 'Do I need to justify my choice of tools if I use alternatives like AWS or Snowflake instead of the ones suggested in the course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'b2799574'},
#  {'question': 'Are there any limitations or risks if I choose to use a completely different tech stack for my capstone project?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'b2799574'},
#  {'question': 'What are some ways I can help support or promote this course if I enjoy it?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2f19301f'},
#  {'question': 'Is there a way to suggest changes or improvements to the course materials?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2f19301f'},
#  {'question': 'Can I collaborate on enhancing the repository, and if so, how?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2f19301f'},
#  {'question': 'What’s the best way to show appreciation for the course if I find it valuable?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2f19301f'},
#  {'question': 'Are there any specific actions I can take to help grow the course’s reach?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2f19301f'},
#  {'question': 'Which operating systems can I use to complete the course without running into compatibility issues?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7c700adb'},
#  {'question': 'Does the course work well on Windows, or is Linux the only recommended option?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7c700adb'},
#  {'question': 'Are there any known problems with using macOS for this course, or will it work just as smoothly as other systems?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7c700adb'},
#  {'question': 'If I don’t have Linux installed, will I still be able to follow along using Windows or macOS without extra setup?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7c700adb'},
#  {'question': 'What’s the best operating system to use for this course, and do I need to switch if I’m already on Windows or macOS?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7c700adb'},
#  {'question': "What should I do if I'm a Windows user and can't run the shell scripts in the later modules?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '44b14808'},
#  {'question': 'Is there a way to complete the course on Windows without setting up WSL?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '44b14808'},
#  {'question': 'Why do the shell scripts in modules like module-05 fail to work on Windows even with Git Bash or MINGW64?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '44b14808'},
#  {'question': 'How have previous students managed to get around the shell script issues on Windows?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '44b14808'},
#  {'question': 'Is the WSL setup mandatory from the beginning, or can I add it later if I run into problems?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '44b14808'},
#  {'question': 'Are there any supplementary materials I can use to deepen my understanding of the course topics?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '76e4baf6'},
#  {'question': "What external resources would help me practice or expand on what we're learning in this course?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '76e4baf6'},
#  {'question': 'Could you suggest some books or online references that align with the course content?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '76e4baf6'},
#  {'question': 'Where can I find additional learning materials to support the lessons in this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '76e4baf6'},
#  {'question': 'Are there any curated lists of tools, articles, or books that complement this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '76e4baf6'},
#  {'question': 'How does the second project submission work if I miss the first deadline?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '48b533a8'},
#  {'question': 'What happens if I fail my initial project attempt—do I get another chance?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '48b533a8'},
#  {'question': 'Is there a limit to how many times I can resubmit a project if I don’t pass the first time?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '48b533a8'},
#  {'question': 'Can I still submit my project after the first deadline if I haven’t tried yet?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '48b533a8'},
#  {'question': 'If I submit my project on time but don’t meet the requirements, will I automatically get a second attempt?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '48b533a8'},
#  {'question': 'What should I do first if I run into a problem while working on an assignment or project?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '954044d1'},
#  {'question': 'Is there a specific way I should phrase my search when looking for solutions to errors online?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '954044d1'},
#  {'question': 'What details should I include when asking for help in Slack to make sure I get useful responses?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '954044d1'},
#  {'question': 'Why is it discouraged to use screenshots or tag instructors when asking for help?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '954044d1'},
#  {'question': 'What’s the best approach if I’ve tried everything but still can’t resolve an issue?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '954044d1'},
#  {'question': 'What details should I include when I reach out for help with a coding issue?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a820b9b3'},
#  {'question': 'Is there a specific format I should follow when describing my problem to get the best assistance?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a820b9b3'},
#  {'question': 'What kind of information do instructors expect me to provide before they can effectively troubleshoot my error?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a820b9b3'},
#  {'question': 'Should I mention the steps I’ve already tried to fix the problem, and why is that important?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a820b9b3'},
#  {'question': 'If I’m stuck on a task from a video, what key pieces of information should I share to help someone understand my issue?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a820b9b3'},
#  {'question': 'What are the first steps I should take to set up GitHub for this course?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f2945cd2'},
#  {'question': 'Can you explain how cloning the course repository helps me with my assignments?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f2945cd2'},
#  {'question': 'Where can I find a guide on creating my own repositories for storing notes and files?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f2945cd2'},
#  {'question': 'Which types of files should I avoid committing to a Git repository, and how do I exclude them?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f2945cd2'},
#  {'question': "Why is it dangerous to include passwords or API keys in a Git repository, even if it's private?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'f2945cd2'},
#  {'question': "Why am I getting a 'missing separator' error when trying to run a Makefile in VS Code?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'eb9d376f'},
#  {'question': 'How can I fix the issue where my Makefile fails with an error about tabs and separators?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'eb9d376f'},
#  {'question': 'What should I do if VS Code is using spaces instead of tabs in my Makefile and causing errors?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'eb9d376f'},
#  {'question': 'Is there a way to ensure my Makefile uses actual tabs instead of spaces in VS Code?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'eb9d376f'},
#  {'question': "What steps can I follow to resolve the 'missing separator' error in a Makefile when working in VS Code?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'eb9d376f'},
#  {'question': 'How can I view an HTML file saved in my WSL Linux environment using a Windows browser?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '72f25f6d'},
#  {'question': 'Is there a command to directly open an HTML file from WSL in my default Windows browser?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '72f25f6d'},
#  {'question': 'What steps do I need to follow to launch a webpage from Linux on WSL using a browser installed on Windows?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '72f25f6d'},
#  {'question': 'Can I specify a different browser, like Firefox, to open HTML files from WSL instead of the default one?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '72f25f6d'},
#  {'question': 'What should I do if the command to open an HTML file from WSL in a Windows browser isn’t working?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '72f25f6d'},
#  {'question': 'How can I remotely access a graphical interface on a Debian Linux VM running on Compute Engine?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1e59afc'},
#  {'question': 'What steps should I follow to install Chrome Remote Desktop on a Linux-based virtual machine?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1e59afc'},
#  {'question': "Why am I getting a '403: Forbidden' error when trying to download the 2021 Yellow Taxi Trip Records from the TLC website?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1e59afc'},
#  {'question': 'Where can I find a working backup of the 2021 Yellow Taxi Trip Records if the official download link fails?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1e59afc'},
#  {'question': "What’s the correct command to extract a .gz file if the standard 'unzip' tool doesn’t work?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1e59afc'},
#  {'question': 'What should I do if my downloaded taxi data file has a .csv.gz extension instead of just .csv?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '71c10610'},
#  {'question': 'Is it necessary to rename the file from .csv.gz to .csv before using it with pandas?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '71c10610'},
#  {'question': 'How can I dynamically set the output filename to match the one in the download URL?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '71c10610'},
#  {'question': 'Will pandas still read the data correctly if the file is compressed as .csv.gz?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '71c10610'},
#  {'question': 'What’s the best way to extract the filename from the taxi data URL to use in my script?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '71c10610'},
#  {'question': 'questions',
#   'course': 'data-engineering-zoomcamp',
#   'document': '17a5aea1'},
#  {'question': 'How can I extract the contents of a compressed parquet file downloaded from the taxi dataset?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '5a275db7'},
#  {'question': 'What command should I use in the terminal to decompress a .gz file containing taxi trip data?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '5a275db7'},
#  {'question': 'Is there a way to work with parquet files directly in Python without converting them to CSV first?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '5a275db7'},
#  {'question': 'What modifications do I need to make in the ingest_data.py script to handle parquet files instead of CSV?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '5a275db7'},
#  {'question': 'After converting a parquet file to CSV in Python, how do I ensure the output file matches the expected format for the rest of the code?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '5a275db7'},
#  {'question': "How can I resolve the error 'wget is not recognized' when trying to use it on my system?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '7ec0f9b0'},
#  {'question': "What are the steps to install wget on a Windows machine if I don't want to use Chocolatey?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '7ec0f9b0'},
#  {'question': 'Is there a way to use wget functionality in Python instead of installing the command-line tool?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7ec0f9b0'},
#  {'question': 'Where can I download a standalone wget executable for Windows if I prefer not to use package managers?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7ec0f9b0'},
#  {'question': 'What should I do if the built-in Windows zip utility fails when extracting the wget download?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7ec0f9b0'},
#  {'question': "When I try to download a file using wget in my terminal on MacOS, I get an error about the website's certificate not being verified. How can I fix this?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'bb1ba786'},
#  {'question': "I'm working in a Jupyter Notebook and running a wget command, but it keeps failing with a certificate error. What should I do differently?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'bb1ba786'},
#  {'question': "Is there an alternative way to download files if the standard wget command isn't working due to certificate issues on my Mac?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'bb1ba786'},
#  {'question': "I installed the wget Python library with pip, but I'm not sure how to use it to bypass certificate verification. What's the correct command?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'bb1ba786'},
#  {'question': "What does adding '--no-check-certificate' do in a wget command, and is it safe to use when downloading files?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'bb1ba786'},
#  {'question': 'How can I make the backslash function as an escape character in Git Bash on Windows?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2f83dbe7'},
#  {'question': 'Is there a specific command I need to run to enable backslash escaping in Git Bash for Windows?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2f83dbe7'},
#  {'question': 'Do I have to add anything to my .bashrc file to use backslashes as escape characters in Git Bash?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2f83dbe7'},
#  {'question': 'What’s the simplest way to configure Git Bash on Windows to treat backslashes as escape characters?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2f83dbe7'},
#  {'question': 'If I want to follow the same setup as Alexey for escape characters in Git Bash, what should I do?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2f83dbe7'},
#  {'question': 'What steps should I follow to securely add sensitive information like API keys or passwords in GitHub Codespaces?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '543ff080'},
#  {'question': 'Where can I find the official documentation for handling environment variables or secrets in Codespaces?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '543ff080'},
#  {'question': 'Is there a way to ensure my credentials remain private when working in a shared Codespaces environment?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '543ff080'},
#  {'question': 'How do I make sure my secrets are available only to my specific Codespaces instance and not others?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '543ff080'},
#  {'question': 'Are there any best practices for managing and organizing multiple secrets when using GitHub Codespaces?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '543ff080'},
#  {'question': "How can I troubleshoot if Docker isn't responding when I try to run commands?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'd407d65b'},
#  {'question': "What should I do if I get an error saying Docker can't connect to the daemon?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'd407d65b'},
#  {'question': 'Is there a way to verify if the Docker service is actually running on my system?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'd407d65b'},
#  {'question': 'I keep seeing a message about the Docker socket not being accessible—what steps should I take?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'd407d65b'},
#  {'question': 'Do I need to run any specific command in PowerShell to fix Docker connectivity issues on Windows?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'd407d65b'},
#  {'question': "What should I do if I get an error saying Docker can't connect because of missing elevated privileges on Windows?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'c9375c56'},
#  {'question': "Is Hyper-V required to run Docker on Windows, and how do I enable it if it's not already active?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'c9375c56'},
#  {'question': "I'm using Windows 10/11 Home—can I still use Docker, and if so, what setup do I need?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'c9375c56'},
#  {'question': "After installing WSL2, I keep seeing an error like 'WslRegisterDistribution failed with error: 0x800701bc.' How can I fix this?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'c9375c56'},
#  {'question': 'Where can I find step-by-step instructions to set up Docker on Windows if I don’t have Hyper-V available?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'c9375c56'},
#  {'question': "What should I do if I get a 'permission denied' error when trying to pull a Docker image that's supposed to be public?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e866156b'},
#  {'question': 'Is it necessary to log in to Docker Hub before pulling images for this course, or can I skip that step?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e866156b'},
#  {'question': "I typed 'docker pull dbpage/pgadmin4' and got an error about the repository not existing—what did I do wrong?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e866156b'},
#  {'question': "Why am I seeing a 'permission denied' error when trying to mount a volume for my PostgreSQL container on macOS M1?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e866156b'},
#  {'question': 'What’s the difference between using Rancher Desktop and Docker Desktop when running PostgreSQL containers with mounted volumes?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e866156b'},
#  {'question': 'How can I remove a local folder that was automatically created by Docker and is now locked with restricted permissions?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '16370470'},
#  {'question': 'What should I do if a Docker-mounted directory prevents my application from starting due to access errors?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '16370470'},
#  {'question': 'Is there a command to forcefully delete a folder that Docker assigned to a non-standard user (like user 999)?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '16370470'},
#  {'question': 'Why does Docker create folders on my machine with unusual ownership, and how can I safely delete them?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '16370470'},
#  {'question': "What steps should I take if I need to relocate a Docker volume folder but can't delete the original due to permission issues?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '16370470'},
#  {'question': 'What should I do if Docker fails to launch or gets stuck during startup on my Windows 10 or 11 machine?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '316df755'},
# ...
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1fc1a14'},
#  {'question': "Which specific role do I need to assign to my service account to resolve the 'storage.buckets.get' access issue?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1fc1a14'},
#  {'question': 'Where in the Google Cloud Console can I update the permissions for my service account to allow bucket access?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1fc1a14'},
#  {'question': "What does the error 'google::cloud::Status(PERMISSION_DENIED: Permanent error GetBucketMetadata)' mean, and how do I address it?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'a1fc1a14'},
#  {'question': 'How can I prepare my PySpark script before sending it to a Dataproc cluster for execution?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '6d67fba9'},
#  {'question': 'What steps do I need to follow to create a Dataproc cluster in the Google Cloud Console?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '6d67fba9'},
#  {'question': 'Which role should I assign to the service account to allow Mage to interact with Dataproc?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '6d67fba9'},
#  {'question': 'Where should I store my PySpark script so that Dataproc can access it during execution?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '6d67fba9'},
#  {'question': 'What prerequisites must be met to ensure Mage can successfully trigger a Dataproc job?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '6d67fba9'},
#  {'question': 'Why does Docker-compose get stuck when trying to install the zip and unzip packages for Linux during dataset extraction?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '06876291'},
#  {'question': 'Is there a way to speed up or bypass the lengthy installation process for zip/unzip dependencies in Docker-compose?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '06876291'},
#  {'question': 'What does the -Y flag do when added to apt-get commands in Docker, and how can it help with package installation issues?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '06876291'},
#  {'question': 'Can I use an alternative method to unpack datasets in Docker without relying on the Linux zip/unzip packages?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '06876291'},
#  {'question': 'Does Python have built-in functionality for handling ZIP files, and would it work as a replacement for the missing Linux tools?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '06876291'},
#  {'question': 'What should I do if I encounter an error while trying to save data from a web application to a Google Cloud Storage bucket?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '690ba010'},
#  {'question': 'Are there specific data types I need to use to avoid issues when writing data to GCS from a web source?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '690ba010'},
#  {'question': 'Why might my data fail to upload to a GCS bucket when coming from a web interface, and how can I fix it?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '690ba010'},
#  {'question': 'Is there a recommended way to handle numeric values when transferring data from the web to Google Cloud Storage?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '690ba010'},
#  {'question': 'What changes should I make to my data schema if I keep getting errors during web-to-GCS data writes?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '690ba010'},
#  {'question': 'Why am I getting an error about mismatched data types when trying to load multiple Parquet files into BigQuery?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'b6fdd91d'},
#  {'question': "What causes the 'Parquet column has type INT which does not match the target cpp_type DOUBLE' error during BigQuery table creation?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'b6fdd91d'},
#  {'question': 'How does BigQuery determine the schema when importing multiple Parquet files from a GCS bucket?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'b6fdd91d'},
#  {'question': 'What should I do if my dataset has inconsistent column types across different files, like some with INT and others with FLOAT?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'b6fdd91d'},
#  {'question': 'How can I ensure all my files have the same schema before uploading them to BigQuery to avoid ingestion errors?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'b6fdd91d'},
#  {'question': "I'm trying to import the FHV dataset into Google Cloud Storage, but I keep getting an error saying the file isn't gzipped. What could be causing this?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '155aa868'},
#  {'question': 'When downloading the FHV data, I encountered a gzip-related error. Is there a specific URL format I should be using to avoid this issue?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '155aa868'},
#  {'question': "The system shows a 'Not a gzipped file' error when I attempt to import FHV data. How can I correct the source link to fix this?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '155aa868'},
#  {'question': 'I followed the steps to import the FHV dataset, but the process fails with a gzip error. What part of the URL might I have missed or entered incorrectly?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '155aa868'},
#  {'question': 'Why does my FHV data import fail with a gzip error, and how can I ensure the correct file path is being used?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '155aa868'},
#  {'question': 'How can I transfer files directly from a list of URLs into a Google Cloud Storage bucket without manually downloading them first?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e78cf960'},
#  {'question': 'Is there a built-in tool or command in GCP to automate loading data from multiple web URLs into a GCS bucket?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e78cf960'},
#  {'question': 'What steps should I follow to batch-import files from external URLs into my Google Cloud Storage bucket efficiently?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e78cf960'},
#  {'question': 'Are there any specific permissions or IAM roles required to load data from URLs into a GCS bucket in Module 3?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e78cf960'},
#  {'question': 'Can you explain the process of using a URL list to populate a GCS bucket, including any potential limitations or best practices?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'e78cf960'},
#  {'question': "What could be causing the 'Bad character (ASCII 0)' error when I run queries on my dataset in Google Cloud Storage?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '9afa1f74'},
#  {'question': 'Is there a specific way I should prepare or format my CSV.GZ files before uploading them to avoid query errors?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '9afa1f74'},
#  {'question': 'Should I avoid using pandas when downloading or processing files for this module, and if so, what alternative method is recommended?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '9afa1f74'},
#  {'question': 'Are there any common mistakes in the schema setup that might lead to this ASCII error when querying data?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '9afa1f74'},
#  {'question': 'Where can I find additional guidance or examples for troubleshooting this issue, like the mentioned Slack conversation?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '9afa1f74'},
#  {'question': 'How can I verify if the BigQuery command-line tool is already installed on my system?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'fac138a7'},
#  {'question': "What should I do if I get an error saying the 'bq' command isn't recognized when trying to use it?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'fac138a7'},
#  {'question': "Is there an alternative command I can use if the standard 'bq' command doesn't work for me?",
#   'course': 'data-engineering-zoomcamp',
#   'document': 'fac138a7'},
#  {'question': 'What steps can I take to troubleshoot when the BigQuery CLI tool seems missing or unavailable?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'fac138a7'},
#  {'question': 'Does the BigQuery command-line tool require any additional setup, and how can I confirm its installation status?',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'fac138a7'},
#  {'question': 'What are the risks of running BigQuery after my GCP free trial ends?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0174dde5'},
#  {'question': 'How can I avoid unexpected charges when using BigQuery in GCP?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0174dde5'},
#  {'question': 'Is there a way to use BigQuery without incurring costs after the free credits expire?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0174dde5'},
#  {'question': 'What steps should I take to monitor my GCP billing while working on Module 3?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0174dde5'},
#  {'question': 'Should I delete my BigQuery datasets immediately after creating them to prevent billing issues?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0174dde5'},
#  {'question': 'What should I do if I get an error about mismatched regions when trying to load data from Google Cloud Storage into BigQuery?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1023ee65'},
#  {'question': 'Is it possible to transfer data between a GCS bucket and a BigQuery dataset if they are located in different regions?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1023ee65'},
#  {'question': 'How can I resolve the issue where my BigQuery dataset and GCS bucket are in separate locations, preventing data loading?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1023ee65'},
#  {'question': 'What steps should I follow if I accidentally created my BigQuery dataset in a different region than my GCS bucket?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1023ee65'},
#  {'question': 'Does BigQuery require the dataset and the GCS bucket to be in the same region for data loading, and how can I fix it if they aren’t?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1023ee65'},
#  {'question': 'questions',
#   'course': 'data-engineering-zoomcamp',
#   'document': 'effd2bfa'},
#  {'question': 'questions',
#   'course': 'data-engineering-zoomcamp',
#   'document': '5b55273c'},
#  {'question': 'How suitable is BigQuery for handling live data updates in a project like this?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1835bfe0'},
#  {'question': 'Does BigQuery support immediate data processing for time-sensitive analysis?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1835bfe0'},
#  {'question': 'Can I rely on BigQuery if my project requires up-to-the-minute insights?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1835bfe0'},
#  {'question': 'Is there a way to incorporate streaming data into BigQuery for near real-time results?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1835bfe0'},
#  {'question': 'Would BigQuery be a good choice if future phases of the project need instant data access?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '1835bfe0'},
#  {'question': 'What should I do if BigQuery throws an error about an unparseable timestamp when loading data from an external table?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '04656af5'},
#  {'question': 'How can I troubleshoot invalid timestamp values in a column when importing data into a materialized table in BigQuery?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '04656af5'},
#  {'question': 'Is there a way to check for corrupted timestamp entries in my Google Cloud Storage file before loading it into BigQuery?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '04656af5'},
#  {'question': 'Why does my data load fail with a timestamp parsing error, and how can I isolate the problematic rows?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '04656af5'},
#  {'question': 'What’s the best approach to handle timestamp format mismatches when moving data from an external table to a materialized table in BigQuery?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '04656af5'},
#  {'question': 'Why am I getting an error in BigQuery about a timestamp not being properly annotated when reading a Parquet file?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2d6536d3'},
#  {'question': "What does the error message 'annotated as a valid Timestamp, please annotate it as TimestampType(MICROS) or TimestampType(MILLIS)' mean in BigQuery?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '2d6536d3'},
#  {'question': 'How can I resolve timestamp formatting issues when writing Parquet files to Google Cloud Storage for use in BigQuery?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2d6536d3'},
#  {'question': "What is the purpose of the `use_deprecated_int96_timestamps` parameter in PyArrow's `write_to_dataset` function?",
#   'course': 'data-engineering-zoomcamp',
#   'document': '2d6536d3'},
#  {'question': 'Are there any compatibility concerns when using PyArrow to write Parquet files that will later be queried in BigQuery?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '2d6536d3'},
#  {'question': 'How can I ensure datetime columns from a Pandas DataFrame are correctly recognized as timestamps when exporting to BigQuery via Parquet files in GCP?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0516ccbe'},
#  {'question': 'What steps should I take in Mage to prevent datetime columns from being converted to integers when writing Parquet files to Google Cloud Storage?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0516ccbe'},
#  {'question': 'Is there a way to explicitly define the schema for datetime columns when exporting data to Parquet in Mage to avoid type mismatches in BigQuery?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0516ccbe'},
#  {'question': 'Why do my datetime columns appear as integers in BigQuery after loading Parquet files exported from Pandas, and how can I fix this?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0516ccbe'},
#  {'question': 'What PyArrow settings should I use in the Mage Data Exporter to ensure datetime columns are properly formatted for BigQuery ingestion?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '0516ccbe'},
#  {'question': 'How can I programmatically set up a BigQuery table that reads data directly from files stored in a Google Cloud Storage bucket?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '6052513d'},
#  {'question': 'What Python code do I need to write to create an external table in BigQuery that automatically detects the schema from Parquet files?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '6052513d'},
#  {'question': 'Is there a way to link a BigQuery table to data in Cloud Storage without importing it, and how do I do that using the Python client library?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '6052513d'},
#  {'question': 'What parameters must I specify when defining an external table in BigQuery that references files in a GCS bucket, and how do I configure them in Python?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '6052513d'},
#  {'question': 'Can you show me a complete example of creating an external BigQuery table from Parquet files in Cloud Storage using the BigQuery Python SDK?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '6052513d'},
#  {'question': 'How can I verify if a specific table already exists in BigQuery before attempting to create it?',
#   'course': 'data-engineering-zoomcamp',
#   'document': '7a71fa2c'},
#  ...]

# %%
relevance_total = []

for q in tqdm(ground_truth):
    doc_id = q['document']
    results = elastic_search(query=q['question'], course=q['course'])
    relevance = [d['id'] == doc_id for d in results]
    relevance_total.append(relevance)
# Out:
#   0%|          | 0/4495 [00:00<?, ?it/s]
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ...
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
example = [
    [True, False, False, False, False], # 1, 
    [False, False, False, False, False], # 0
    [False, False, False, False, False], # 0 
    [False, False, False, False, False], # 0
    [False, False, False, False, False], # 0 
    [True, False, False, False, False], # 1
    [True, False, False, False, False], # 1
    [True, False, False, False, False], # 1
    [True, False, False, False, False], # 1
    [True, False, False, False, False], # 1 
    [False, False, True, False, False],  # 1/3
    [False, False, False, False, False], # 0
]

# 1 => 1
# 2 => 1 / 2 = 0.5
# 3 => 1 / 3 = 0.3333
# 4 => 0.25
# 5 => 0.2
# rank => 1 / rank
# none => 0

# %%
def hit_rate(relevance_total):
    cnt = 0

    for line in relevance_total:
        if True in line:
            cnt = cnt + 1

    return cnt / len(relevance_total)

# %%
#Mean Reciprocal Rank (mrr)
def mrr(relevance_total):
    total_score = 0.0

    for line in relevance_total:
        for rank in range(len(line)):
            if line[rank] == True:
                total_score = total_score + 1 / (rank + 1)

    return total_score / len(relevance_total)

# %%
hit_rate(example)
# Out:
# 0.5833333333333334

# %%
mrr(example)
# Out:
# 0.5277777777777778

# %%
hit_rate(relevance_total), mrr(relevance_total)
# Out:
# (0.5842046718576196, 0.4464441972562101)

# %%
def evaluate(ground_truth, search_function):
    relevance_total = []

    for q in tqdm(ground_truth):
        doc_id = q['document']
        results = search_function(q)
        relevance = [d['id'] == doc_id for d in results]
        relevance_total.append(relevance)

    return {
        'hit_rate': hit_rate(relevance_total),
        'mrr': mrr(relevance_total),
    }

# %%
evaluate(ground_truth, lambda q: elastic_search(q['question'], q['course']))
# Out:
#   0%|          | 0/4495 [00:00<?, ?it/s]
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ...
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/python/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# {'hit_rate': 0.5842046718576196, 'mrr': 0.4464441972562101}
